# %%
import requests

# %%
resp1 = requests.get("https://www.taxlok.com/online-easy-tax-new/login.html/id=1")
if resp1.status_code == 200:
#     print("Request successful")
    cookies = resp1.headers.get('Set-Cookie')
    resp2 = requests.get("https://www.taxlok.com/captcha/Default.aspx", headers={'cookie': cookies})
    if resp2.status_code == 200:
        with open("captcha_image.jpg", "wb") as f:
            f.write(resp2.content)
        print("Captcha image saved as captcha_image.jpg")
# Out:
# Captcha image saved as captcha_image.jpg

# %%
username = "8101787250"
password = "8101787250"
captcha = "JF7H8VU"

# %%
resp3 = requests.post("https://www.taxlok.com/online-easy-tax-new/login.html/id=1",
                      headers={'cookie': cookies})

# %%
resp3.headers
# Out:
# {'Cache-Control': 'private', 'Content-Type': 'text/html', 'Server': 'Microsoft-IIS/10.0', 'X-AspNet-Version': '4.0.30319', 'X-Powered-By': 'ASP.NET', 'Date': 'Sun, 28 Dec 2025 18:35:33 GMT', 'Content-Length': '11'}

# %%
resp.headers
# Out:
# {'Cache-Control': 'private', 'Content-Type': 'image/jpeg; charset=utf-8', 'Server': 'Microsoft-IIS/10.0', 'Set-Cookie': 'ASP.NET_SessionId=a2wn2a1vubi15zwt5k0m0ymg; path=/; HttpOnly; SameSite=Lax', 'X-AspNet-Version': '4.0.30319', 'X-Powered-By': 'ASP.NET', 'Date': 'Sun, 28 Dec 2025 17:50:02 GMT', 'Content-Length': '2621'}

# %%
resp.content
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00H\x00H\x00\x00\xff\xe1\x00VExif\x00\x00MM\x00*\x00\x00\x00\x08\x00\x04\x011\x00\x02\x00\x00\x00\x10\x00\x00\x00>Q\x10\x00\x01\x00\x00\x00\x01\x01\x00\x00\x00Q\x11\x00\x04\x00\x00\x00\x01\x00\x00\x0b\x12Q\x12\x00\x04\x00\x00\x00\x01\x00\x00\x0b\x12\x00\x00\x00\x00Adobe Fireworks\x00\xff\xdb\x00C\x00\x08\x06\x06\x07\x06\x05\x08\x07\x07\x07\t\t\x08\n\x0c\x14\r\x0c\x0b\x0b\x0c\x19\x12\x13\x0f\x14\x1d\x1a\x1f\x1e\x1d\x1a\x1c\x1c $.\' ",#\x1c\x1c(7),01444\x1f\'9=82<.342\xff\xdb\x00C\x01\t\t\t\x0c\x0b\x0c\x18\r\r\x182!\x1c!22222222222222222222222222222222222222222222222222\xff\xc0\x00\x11\x08\x002\x00\x8c\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1f\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\xff\xc4\x00\xb5\x10\x00\x02\x01\x03\x03\x02\x04\x03\x05\x05\x04\x04\x00\x00\x01}\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13Qa\x07"q\x142\x81\x91\xa1\x08#B\xb1\xc1\x15R\xd1\xf0$3
# ...

# %%
with open("captcha_image.jpg", "wb") as f:
    f.write(resp.content)
